# %%
def cal(a,b):
    print('the sum is', a+b)
    print('the diffenrence is', a-b)
    print('the product is', a*b)
    print('the dividend is', a/b)


cal(10,20)
cal(5,6)
# Out:
# the sum is 30
# the diffenrence is -10
# the product is 200
# the dividend is 0.5
# the sum is 11
# the diffenrence is -1
# the product is 30
# the dividend is 0.8333333333333334

# %%
# wap to print hello world using function 

def m1():
    print('hello world')

m1()     #calling a function
# Out:
# hello world

# %%
def wish(name):
    print('Hello {}'.format(name))
    
wish('ritik')
# Out:
# Hello ritik

# %%
# wap to take the numbers as parameter and print the square of that number

def sq(a):
    print(a**2)

sq(5)
sq(10)
# Out:
# 25
# 100

# %%
# wap to accept 2 nos and return sum 

def add(a,b):
    return a+b

add(5,10)
# Out:
# 15

# %%
def m1():
    print('hello')
result=m1()
print(result)
# Out:
# hello
# None

# %%
def add(a,b):
    print(a+b)

c=add(5,10)
print(c)
# Out:
# 15
# None
