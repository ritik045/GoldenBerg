# %%
t=(10,20,30,'aaa',True)
print(t[0])
print(t[3])
print(t[2:4])
print(t)
print(t[-2])
# Out:
# 10
# aaa
# (30, 'aaa')
# (10, 20, 30, 'aaa', True)
# aaa

# %%
t=(20)
print(type(t))
s=(20,)
print(type(s))
# Out:
# <class 'int'>
# <class 'tuple'>

# %%
import sys
l=[10,20,30]
t=(10,20,30)
print(sys.getsizeof(l))
print(sys.getsizeof(t))
# Out:
# 88
# 64

# %%
# tuple creation

l=[10,20,30]
t=tuple(l)
print(type(t))
print(type(l))
print(id(l))
print(id(t))
# Out:
# <class 'tuple'>
# <class 'list'>
# 2109442523328
# 2109442306880

# %%
t=(10,20,30,40)
print(t[0])
print(t[-1])
print(t[1:])
print(t[:100])
# Out:
# 10
# 40
# (20, 30, 40)
# (10, 20, 30, 40)

# %%
# mathematical operation

t1=(10,20,30)
t2=(40,50,60)
t3=t1+t2
print(t3)
print(t1*3)
# Out:
# (10, 20, 30, 40, 50, 60)
# (10, 20, 30, 10, 20, 30, 10, 20, 30)

# %%
t=(2,8,1,6,4,3)
print(sorted(t))
l=tuple(sorted(t))
print(l)
l1=tuple(sorted(t,reverse=True))
print(l1)
# Out:
# [1, 2, 3, 4, 6, 8]
# (1, 2, 3, 4, 6, 8)
# (8, 6, 4, 3, 2, 1)

# %%
t=(9,3,6,2,5,7)
print(min(t))
print(max(t))

t1=('aaa','nnn','bbb','zzz')
print(min(t1))
print(max(t1))

t2=('aa','AA','Ab')
print(min(t2))
print(max(t2))
# Out:
# 2
# 9
# aaa
# zzz
# AA
# aa

# %%
# packing and unpacking

a=10
b=20
c=30
t=a,b,c
print(t)

a,b,c=t
print(a,b,c) #unpacking
# Out:
# (10, 20, 30)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 9
#       6 t=a,b,c
#       7 print(t)
# ----> 9 a,b=t
#      10 print(a,b,c) #unpacking
#
# ValueError: too many values to unpack (expected 2)

# %%
t=(10, 20, 30, 40)
[*a]=t
print(a)
print(tuple(a))
# Out:
# [10, 20, 30, 40]
# (10, 20, 30, 40)

# %%
t=(10, 20, 30, 40)
a,b,*c=t
print(c)
# Out:
# [30, 40]

# %%
t=(10,20,30,40,50,60)
*a,=t
print(a)
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
t=(x for x in range(6))
print(t)
# Out:
# <generator object <genexpr> at 0x000001CF14515300>

# %%
t=[x for x in range(6)]
print(t)
# Out:
# [0, 1, 2, 3, 4, 5]
