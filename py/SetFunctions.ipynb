# %%
# creation of set object 

l=[10,10,10,20,20,30,30,30,40,40]
s=set(l)
print(s)
# Out:
# {40, 10, 20, 30}

# %%
d={111:'aaa',222:'bbb'}
s=set(d)
print(s)
# Out:
# {222, 111}

# %%
s={'abc','def','ghi'}
s1=set(s)
print(s1)
print(type(s1))
# Out:
# {'abc', 'def', 'ghi'}
# <class 'set'>

# %%
s=eval(input('enter the set'))
print(s)
print(type(s))
# Out:
# {10, 20, 30}
# <class 'set'>

# %%
s={}
print(type(s))
s1=set()
print(s1)
# Out:
# <class 'dict'>
# set()

# %%
s=set()
s.add(10)
s.add('aa')
s.add(True)
print(s)
# Out:
# {True, 10, 'aa'}

# %%
s=set()
s.update(range(1,6),'abc','def',[10,20,30])
print(s)
# Out:
# {1, 2, 3, 4, 5, 'b', 10, 'a', 'd', 'f', 20, 'e', 'c', 30}

# %%
s=set()
s.update([10,20,30,[10,20]])
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 s=set()
# ----> 2 s.update([10,20,30,[10,20]])
#       3 print(s)
#
# TypeError: unhashable type: 'list'

# %%
s={10,50,40,80,20}
s.discard(50)
print(s)
s.remove(10)
print(s)
s.clear()
print(s)
# Out:
# {80, 20, 40, 10}
# {80, 20, 40}
# set()

# %%
s=[10,20,30,40]
print(type(s))
l=set(s)
print(l)
print(type(l))
# Out:
# <class 'list'>
# {40, 10, 20, 30}
# <class 'set'>

# %%
s={10,20,30}
s.add(40)
s.add('aa')
s.add(True)
print(s)
s.update('bb','cc',{60,70},(80,90),[40,50],{111:'aaa'})
print(s)
# Out:
# {True, 40, 10, 'aa', 20, 30}
# {True, 'b', 70, 40, 10, 'aa', 60, 80, 111, 50, 20, 90, 123, 'c', 30}

# %%
# mathematical operations

# union 

x={10,20,30,40}
y={30,40,50,60}
print(x.union(y))
print(x or y)
